# %%
#Requirements
import pandas as pd
import seaborn as sns
from datetime import date 
import matplotlib.pyplot as plt

# %%
censes=pd.read_csv('./India Census 2011 Data.csv')

# %%
censes.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %%
censes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
censes=censes.drop(['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'],axis=1)

# %%
censes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Secondary_Education   640 non-null    int64
#  14  Higher_Education      640 non-null    int64
# ...

# %%
censes.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %%
censes.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# 0    439654   229064        190899           38165               34680
# 1    335649   214866        162578           52288               55299
# 2     93770    75079         53265           21814               20869
# 3     86236    51873         39839           12034                8266
# 4    261724   161393        117677           43716               54264
#
#    Agricultural_Workers  Household_Workers  Secondary_Education  \
# ...

# %%
Population_data=censes

# %%
df2=pd.read_csv('./archive/NIFTY50_all.csv')

# %%
df2.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  235192.000000  235192.000000  235192.000000  235192.000000
# mean     1266.196349    1267.759708    1286.581440    1247.488465
# std      2581.370320    2585.259609    2619.649216    2546.621396
# min         0.000000       8.500000       9.750000       8.500000
# 25%       274.300000     275.000000     279.500000     269.600000
# 50%       566.500000     567.025000     576.900000     556.500000
# 75%      1242.200000    1243.312500    1263.000000    1221.650000
# max     32861.950000   33399.950000   33480.000000   32468.100000
#
#                 Last          Close          VWAP        Volume      Turnover  \
# count  235192.000000  235192.000000  235192.00000  2.351920e+05  2.351920e+05
# mean     1266.388302    1266.554351    1267.13230  3.045903e+06  1.610138e+14
# std      2581.392543    2582.140942    2582.69998  7.333981e+06  3.298085e+14
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235192 entries, 0 to 235191
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                235192 non-null  object
#  1   Symbol              235192 non-null  object
#  2   Series              235192 non-null  object
#  3   Prev Close          235192 non-null  float64
#  4   Open                235192 non-null  float64
#  5   High                235192 non-null  float64
#  6   Low                 235192 non-null  float64
#  7   Last                235192 non-null  float64
#  8   Close               235192 non-null  float64
#  9   VWAP                235192 non-null  float64
#  10  Volume              235192 non-null  int64
#  11  Turnover            235192 non-null  float64
#  12  Trades              120344 non-null  float64
#  13  Deliverable Volume  219115 non-null  float64
#  14  %Deliverble         219115 non-null  float64
# ...

# %%
df2.head()
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  962.90  984.72  27294366  2.687719e+15     NaN           9859619.0
# 1  893.90  941.38   4581338  4.312765e+14     NaN           1453278.0
# 2  884.20  888.09   5124121  4.550658e+14     NaN           1069678.0
# 3  921.55  929.17   4609762  4.283257e+14     NaN           1260913.0
# 4  969.30  965.65   2977470  2.875200e+14     NaN            816123.0
#
#    %Deliverble
# 0       0.3612
# 1       0.3172
# 2       0.2088
# 3       0.2735
# ...

# %%
df2=df2.drop(['Deliverable Volume','%Deliverble','Trades'],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235192 entries, 0 to 235191
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        235192 non-null  object
#  1   Symbol      235192 non-null  object
#  2   Series      235192 non-null  object
#  3   Prev Close  235192 non-null  float64
#  4   Open        235192 non-null  float64
#  5   High        235192 non-null  float64
#  6   Low         235192 non-null  float64
#  7   Last        235192 non-null  float64
#  8   Close       235192 non-null  float64
#  9   VWAP        235192 non-null  float64
#  10  Volume      235192 non-null  int64
#  11  Turnover    235192 non-null  float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 21.5+ MB

# %%
before_11_data=df2[df2['Date']<='2011-12-31']

# %%
before_11_data.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  121953.000000  121953.000000  121953.000000  121953.000000
# mean      726.807836     727.804447     741.638418     712.829571
# std       821.574135     822.571199     838.417641     804.486454
# min         0.000000       8.500000       9.750000       8.500000
# 25%       220.250000     220.100000     225.000000     216.000000
# 50%       465.950000     466.100000     475.700000     456.150000
# 75%       938.200000     940.000000     957.000000     921.000000
# max     16855.900000   16800.000000   16875.250000   16253.000000
#
#                 Last          Close           VWAP        Volume      Turnover
# count  121953.000000  121953.000000  121953.000000  1.219530e+05  1.219530e+05
# mean      726.743160     726.791608     727.377515  1.426389e+06  7.599006e+13
# std       820.580896     820.676101     821.473545  3.360105e+06  1.456501e+14
# ...

# %%
list_of_companies=before_11_data['Symbol'].unique()

# %%
list_of_companies
# Out:
# array(['MUNDRAPORT', 'ASIANPAINT', 'UTIBANK', 'AXISBANK', 'BAJAJ-AUTO',
#        'BAJAJFINSV', 'BAJAUTOFIN', 'BAJFINANCE', 'BHARTI', 'BHARTIARTL',
#        'BPCL', 'BRITANNIA', 'CIPLA', 'COALINDIA', 'DRREDDY', 'EICHERMOT',
#        'GAIL', 'GRASIM', 'HCLTECH', 'HDFC', 'HDFCBANK', 'HEROHONDA',
#        'HEROMOTOCO', 'HINDALC0', 'HINDALCO', 'HINDLEVER', 'HINDUNILVR',
#        'ICICIBANK', 'INDUSINDBK', 'INFOSYSTCH', 'INFY', 'IOC', 'ITC',
#        'JSWSTL', 'JSWSTEEL', 'KOTAKMAH', 'KOTAKBANK', 'LT', 'M&M',
#        'MARUTI', 'NESTLEIND', 'NTPC', 'ONGC', 'POWERGRID', 'RELIANCE',
#        'SBIN', 'SHREECEM', 'SUNPHARMA', 'TELCO', 'TATAMOTORS', 'TISCO',
#        'TATASTEEL', 'TCS', 'TECHM', 'TITAN', 'ULTRACEMCO', 'UNIPHOS',
#        'SESAGOA', 'WIPRO', 'ZEETELE', 'ZEEL'], dtype=object)

# %%
before_11_data['Symbol'][before_11_data['Symbol']=='HINDALC0']='HINDALCO'
before_11_data['Symbol'][before_11_data['Symbol']=='HINDLEVER']='HINDUNILVR'
before_11_data['Symbol'][before_11_data['Symbol']=='BHARTI']='BHARTIARTL'
before_11_data['Symbol'][before_11_data['Symbol']=='KOTAKBANK']='KOTAKMAH'
before_11_data['Symbol'][before_11_data['Symbol']=='TISCO']='TATASTEEL'
before_11_data['Symbol'][before_11_data['Symbol']=='UTIBANK']="AXISBANK"
before_11_data['Symbol'][before_11_data['Symbol']=='ZEETELE']="ZELE"
before_11_data['Symbol'][before_11_data['Symbol']=='HEROHONDA']="HEROMOTOCO"
# Out:
# c:\Users\crazi\Desktop\appPrograms\python3.7.4\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Users\crazi\Desktop\appPrograms\python3.7.4\lib\site-packages\pandas\core\generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# c:\Users\crazi\Desktop\appPrograms\python3.7.4\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
list_of_companies=before_11_data['Symbol'].unique()
list_of_companies
# Out:
# array(['MUNDRAPORT', 'ASIANPAINT', 'AXISBANK', 'BAJAJ-AUTO', 'BAJAJFINSV',
#        'BAJAUTOFIN', 'BAJFINANCE', 'BHARTIARTL', 'BPCL', 'BRITANNIA',
#        'CIPLA', 'COALINDIA', 'DRREDDY', 'EICHERMOT', 'GAIL', 'GRASIM',
#        'HCLTECH', 'HDFC', 'HDFCBANK', 'HEROMOTOCO', 'HINDALCO',
#        'HINDUNILVR', 'ICICIBANK', 'INDUSINDBK', 'INFOSYSTCH', 'INFY',
#        'IOC', 'ITC', 'JSWSTL', 'JSWSTEEL', 'KOTAKMAH', 'LT', 'M&M',
#        'MARUTI', 'NESTLEIND', 'NTPC', 'ONGC', 'POWERGRID', 'RELIANCE',
#        'SBIN', 'SHREECEM', 'SUNPHARMA', 'TELCO', 'TATAMOTORS',
#        'TATASTEEL', 'TCS', 'TECHM', 'TITAN', 'ULTRACEMCO', 'UNIPHOS',
#        'SESAGOA', 'WIPRO', 'ZELE', 'ZEEL'], dtype=object)

# %%
cmpy_df={}
for c in list_of_companies:
    df=before_11_data[before_11_data['Symbol']==c]
    df=df.drop(['Symbol'],axis=1)
    cmpy_df[c]=df

# %%
len(cmpy_df)
# Out:
# 54

# %%
for i, j  in cmpy_df.items():
    print(f"{i} : {len(j)}")
# Out:
# MUNDRAPORT : 1011
# ASIANPAINT : 2995
# AXISBANK : 2995
# BAJAJ-AUTO : 891
# BAJAJFINSV : 890
# BAJAUTOFIN : 2611
# BAJFINANCE : 313
# BHARTIARTL : 2463
# BPCL : 2995
# BRITANNIA : 2994
# CIPLA : 2995
# COALINDIA : 287
# DRREDDY : 2995
# EICHERMOT : 2990
# GAIL : 2674
# GRASIM : 2995
# HCLTECH : 2989
# HDFC : 2995
# HDFCBANK : 2995
# HEROMOTOCO : 2995
# HINDALCO : 2995
# HINDUNILVR : 2995
# ICICIBANK : 2995
# INDUSINDBK : 2674
# INFOSYSTCH : 2870
# INFY : 125
# IOC : 2995
# ITC : 2995
# JSWSTL : 123
# JSWSTEEL : 1560
# KOTAKMAH : 2674
# LT : 1873
# M&M : 2995
# MARUTI : 2116
# NESTLEIND : 495
# NTPC : 1777
# ONGC : 2995
# POWERGRID : 1048
# RELIANCE : 2995
# SBIN : 2995
# SHREECEM : 2674
# SUNPHARMA : 2995
# TELCO : 999
# TATAMOTORS : 1996
# TATASTEEL : 2995
# TCS : 1828
# TECHM : 1324
# TITAN : 2995
# ULTRACEMCO : 1829
# UNIPHOS : 1976
# SESAGOA : 2994
# WIPRO : 2995
# ZELE : 1796
# ZEEL : 1199

# %%
for i, comp in enumerate(cmpy_df.keys(), 0):
    if(i%9==0):
        plt.figure(figsize=(15, 10))
        # plt.subplots_adjust(top=1.25, bottom=1.2)

    
    plt.subplot(3, 3, (i)%9+1)
    plt.plot(cmpy_df[comp]['Close'])
    plt.ylabel('Close')
    plt.xlabel(None)
    import matplotlib.dates as mdates
    plt.gcf().autofmt_xdate()
    myFmt = mdates.DateFormatter('%y')
    plt.gca().xaxis.set_major_formatter(myFmt)
    
    
    plt.title(f"Closing Price of {comp}")
    

plt.tight_layout()

# %%
for company in cmpy_df.values():
    company['Daily Return'] = company['Close'].pct_change()

# %%
for company in cmpy_df.values():
    print(company)
# Out:
#             Date Series  Prev Close    Open     High     Low    Last   Close  \
# 0     2007-11-27     EQ      440.00  770.00  1050.00  770.00  959.00  962.90
# 1     2007-11-28     EQ      962.90  984.00   990.00  874.00  885.00  893.90
# 2     2007-11-29     EQ      893.90  909.00   914.75  841.00  887.00  884.20
# 3     2007-11-30     EQ      884.20  890.00   958.00  890.00  929.00  921.55
# 4     2007-12-03     EQ      921.55  939.75   995.00  922.00  980.00  969.30
# ...          ...    ...         ...     ...      ...     ...     ...     ...
# 1006  2011-12-26     EQ      124.90  125.50   125.50  120.10  123.25  123.55
# 1007  2011-12-27     EQ      123.55  124.50   127.90  123.00  124.50  125.45
# 1008  2011-12-28     EQ      125.45  126.65   126.65  119.25  120.05  120.60
# 1009  2011-12-29     EQ      120.60  120.45   126.75  118.70  124.00  124.20
# 1010  2011-12-30     EQ      124.20  123.60   123.60  119.65  120.10  120.05
#
# ...

# %%
for i, comp in enumerate(cmpy_df.keys(), 0):
    if(i%9==0):
        plt.figure(figsize=(15, 10))
        # plt.subplots_adjust(top=1.25, bottom=1.2)

    
    plt.subplot(3, 3, (i)%9+1)
    cmpy_df[comp]['Daily Return'].hist()
    plt.ylabel('Daily Return')
    plt.xlabel(None)
   
    plt.title(f"Closing Price of {comp}")
    

plt.tight_layout()

# %%
plt.figure(figsize=(10, 8))
for i in cmpy_df.keys():
    closing_df=cmpy_df[i]['Close']
    daily_returns=closing_df.pct_change()
    rets = daily_returns.dropna()

    import numpy as np
    area = np.pi * 20

    plt.scatter(rets.mean(), rets.std(), s=area)
    plt.xlabel('Expected return')
    plt.ylabel('Risk')

    # for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(i, xy=(rets.mean(), rets.std()), textcoords='offset points', ha='right', va='bottom')
# Out:
# c:\Users\crazi\Desktop\appPrograms\python3.7.4\lib\site-packages\ipykernel_launcher.py:15: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   from ipykernel import kernelapp as app

# %%
#So Analysing Companies with low risk high returns
# 1. NESTLEIND
# 2. ASIANPAINTS
# 3. NTPC
# 4. ULTRACemo
 
df=cmpy_df['NESTLEIND']
df
# Out:
#               Date Series  Prev Close     Open    High      Low    Last  \
# 150694  2010-01-08     EQ     2512.95  2555.00  2575.0  2475.20  2476.0
# 150695  2010-01-11     EQ     2494.65  2401.00  2515.0  2400.00  2500.0
# 150696  2010-01-12     EQ     2498.95  2540.00  2540.0  2471.35  2505.0
# 150697  2010-01-13     EQ     2502.85  2502.85  2540.0  2480.00  2489.8
# 150698  2010-01-14     EQ     2489.35  2535.00  2595.0  2470.00  2560.0
# ...            ...    ...         ...      ...     ...      ...     ...
# 151184  2011-12-26     EQ     4087.45  4093.70  4151.0  4088.00  4140.0
# 151185  2011-12-27     EQ     4139.15  4149.00  4240.0  4145.00  4204.0
# 151186  2011-12-28     EQ     4219.05  4210.15  4239.0  4145.00  4175.0
# 151187  2011-12-29     EQ     4207.65  4197.00  4210.0  4100.00  4100.0
# 151188  2011-12-30     EQ     4112.55  4135.00  4135.0  4016.00  4098.9
#
#           Close     VWAP  Volume      Turnover  Daily Return
# ...

# %%
data = df.filter(['Close'])
dataset = data.values
training_data_len = int(np.ceil( len(dataset) * .8 ))
training_data_len
# Out:
# 396

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00263931],
#        [0.00478064],
#        [0.00672277],
#        [0.        ],
#        [0.03926597],
#        [0.01202629],
#        [0.02330561],
#        [0.03324038],
#        [0.02646781],
#        [0.01835068],
#        [0.01974503],
#        [0.01638365],
#        [0.03861859],
#        [0.04855336],
#        [0.02173697],
#        [0.02133858],
#        [0.03523231],
#        [0.03747323],
#        [0.03934067],
#        [0.02975449],
#        [0.0383696 ],
#        [0.07776007],
#        [0.1510134 ],
#        [0.12989891],
#        [0.12345003],
#        [0.11448633],
#        [0.10582142],
#        [0.09929784],
#        [0.08074797],
#        [0.07509586],
#        [0.04758229],
#        [0.03129824],
#        [0.04250286],
#        [0.03498332],
#        [0.06849758],
#        [0.06777551],
#        [0.06961805],
#        [0.07203327],
#        [0.10547284],
#        [0.11782282],
#        [0.12740899],
#        [0.12479458],
#        [0.1212091 ],
# ...

# %%
train_data = scaled_data[0:int(training_data_len), :]
days=100
x_train = []
y_train = []

for i in range(days, len(train_data)):
    x_train.append(train_data[i-days:i, 0])
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(150, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(80, return_sequences=False))
model.add(Dense(35))
model.add(Dense(12))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 296/296 [==============================] - 8s 19ms/step - loss: 0.0111

# %%
test_data = scaled_data[training_data_len - days: , :]

x_test = []
y_test = dataset[training_data_len:, :]
for i in range(days, len(test_data)):
    x_test.append(test_data[i-days:i, 0])
    
x_test = np.array(x_test)

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000236E6A39438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 141.98462803610295

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price INR ', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# c:\Users\crazi\Desktop\appPrograms\python3.7.4\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
valid
# Out:
#           Close  Predictions
# 151090  4300.45  4403.499023
# 151091  4238.35  4398.980469
# 151092  4133.80  4392.026367
# 151093  4218.75  4376.659180
# 151094  4165.25  4363.990234
# ...         ...          ...
# 151184  4139.15  4256.447754
# 151185  4219.05  4248.786133
# 151186  4207.65  4251.354980
# 151187  4112.55  4258.898438
# 151188  4094.85  4261.706543
#
# [99 rows x 2 columns]
